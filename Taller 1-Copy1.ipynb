# %% [markdown]
# # CRÍTICA VISUALIZACIÓN DE DATOS

# %% [markdown]
# ## Primera image

# %% [markdown]
# ![GlobalFastFoodLN-jumbo.webp](attachment:GlobalFastFoodLN-jumbo.webp)

# %% [markdown]
# ## Framework What, Why, How?
#
# ### 1.What?

# %% [markdown]
# #### Tipo de datos: posicion y cuadricula
# #### Tipo de dataset: Tabla
# #### Tipo de atributo : Categorico
# #### Direccion: Divergente

# %% [markdown]
# ### 2.Why?

# %% [markdown]
# #### Verbos:buscar localizacion conocida ,analizar de forma divertida.
# #### Sustantivos:caracteristicas los diferenres  colores de los puntos ,dependencia de las categorias de cada punto por su color.

# %% [markdown]
# ### 3.How?

# %% [markdown]
# #### Forma de punto separados ,
# #### Color: amarrillo,vinotinto y azul claro

# %% [markdown]
# ### 4.Marcas
# #### Marcas de puntos
# ### 5.Canales
# #### Canal de posicion espacial tanto verticar como horizontal,canal de color para atributo categorico y canal de tamaño
# ### 6.Reglas generales
# #### La imagen se entiden bien ,ellos resaltan los puntos de color vinotintos que son los paises con ingresos medio bajos
# #### el texto que usan en la imagen es moderado dado que ,son los nombres de algunos paises ,pero no todos tiene nombre .

# %% [markdown]
# ## Segunda imagen

# %% [markdown]
# ![2552_IIB_Left_v_Right_World.png](attachment:2552_IIB_Left_v_Right_World.png)

# %% [markdown]
# ### 1.What?
# ####  Tipos de datos: Atributos,Listas
# ####  Tipo de Atributo :Categorico ,Dependencias.
# ####  Dirrecion :Secuencial.
# ### 2.Why?
# ####  Verbo: Imagen didactica, Deriva lo que es estar en la derecha o izquierda,Es uan Consulta de comparar.
# ####  Sustantivo: Se encuentar informacion de la derecha o izquierda , Diferencias entre la derecha e izquierda.
# ### 3.How?
# ####  Diferentes tamaños y formas.
# ### 4.Marcas
# ####    Marca de Area, linea ,puntos , similitud.
# ### 5.Canales
# ####  Canal de Diferentes formas .
# ### 6.Reglas Generales
# #### Ingustificado :Tiene mucho informacio y texto ,la imagen se ve saturada de figuras y lestras con espacio minimo entre ellas.

# %% [markdown]
# ## Enlaces de las imagenes
# ### https://www.nytimes.com/2018/10/16/learning/whats-going-on-in-this-graph-oct-17-2018.html
# ### https://informationisbeautiful.net/visualizations/left-vs-right-world/
